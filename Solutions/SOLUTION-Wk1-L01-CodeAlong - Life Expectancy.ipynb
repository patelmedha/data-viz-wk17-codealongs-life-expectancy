# %% [markdown]
# # Week 17, Lecture 01 CodeAlong
# - Coefficients & Feature Importance

# %% [markdown]
# ## Lesson Objectives

# %% [markdown]
# - By the end of this lesson, students will be able to:
#     - Extract feature names from sklearn v1.1 objects
#     - Extract and visualize coefficients
#     - Save models to a joblib file

# %% [markdown]
# ### Life Expectancy

# %% [markdown]
# > Task Inspired by: https://medium.com/@shanzehhaji/using-a-linear-regression-model-to-predict-life-expectancy-de3aef66ac21
#
# - Kaggle Dataset on Life Expectancy:
#     - https://www.kaggle.com/datasets/kumarajarshi/life-expectancy-who

# %%
## Our standard imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as miss

## Preprocessing tools
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer, make_column_selector
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.impute import SimpleImputer

## Models & evaluation metrics
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
import joblib

## setting random state for reproducibility
SEED = 321
np.random.seed(SEED)
## Matplotlib style
fav_style = ('ggplot','tableau-colorblind10')
fav_context  ={'context':'notebook', 'font_scale':1.1}
plt.style.use(fav_style)
sns.set_context(**fav_context)
plt.rcParams['savefig.transparent'] = False
plt.rcParams['savefig.bbox'] = 'tight'

# %%
## Importing Custom Functions
import sys,os
sys.path.append(os.path.abspath("../"))
# %load_ext autoreload
# %autoreload 2
from CODE import data_enrichment as de

# %%
import pandas as pd
df = pd.read_csv("../Data/Life Expectancy Data.csv")
df.info()
df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
#  12  Polio                            2919 non-null   float64
#  13  Total expenditure                2712 non-null   float64
#  14  Diphtheria                       2919 non-null   float64
#  15   HIV/AIDS                        2938 non-null   float64
#  16  GDP                              2490 non-null   float64
#  17  Population                       2286 non-null   float64
#  18   thinness  1-19 years            2904 non-null   float64
#  19   thinness 5-9 years              2904 non-null   float64
#  20  Income composition of resources  2771 non-null   float64
#  21  Schooling                        2775 non-null   float64
# dtypes: float64(16), int64(4), object(2)
# memory usage: 505.1+ KB
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   ...  \
# 0             62     0.01               71.279624         65.0      1154  ...
# 1             64     0.01               73.523582         62.0       492  ...
# 2             66     0.01               73.219243         64.0       430  ...
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0    6.0               8.16         65.0        0.1  584.259210  33736494.0
# 1   58.0               8.18         62.0        0.1  612.696514    327582.0
# 2   62.0               8.13         64.0        0.1  631.744976  31731688.0
#
#     thinness  1-19 years   thinness 5-9 years  \
# 0                   17.2                 17.3
# 1                   17.5                 17.5
# 2                   17.7                 17.7
#
#    Income composition of resources  Schooling
# 0                            0.479       10.1
# 1                            0.476       10.0
# 2                            0.470        9.9
#
# [3 rows x 22 columns]

# %%
# clean extra spaces
df.columns = df.columns.str.strip()
df
# Out:
#           Country  Year      Status  Life expectancy  Adult Mortality  \
# 0     Afghanistan  2015  Developing             65.0            263.0
# 1     Afghanistan  2014  Developing             59.9            271.0
# 2     Afghanistan  2013  Developing             59.9            268.0
# 3     Afghanistan  2012  Developing             59.5            272.0
# 4     Afghanistan  2011  Developing             59.2            275.0
# ...           ...   ...         ...              ...              ...
# 2933     Zimbabwe  2004  Developing             44.3            723.0
# 2934     Zimbabwe  2003  Developing             44.5            715.0
# 2935     Zimbabwe  2002  Developing             44.8             73.0
# 2936     Zimbabwe  2001  Developing             45.3            686.0
# 2937     Zimbabwe  2000  Developing             46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# 0                62     0.01               71.279624         65.0     1154
# 1                64     0.01               73.523582         62.0      492
# 2                66     0.01               73.219243         64.0      430
# 3                69     0.01               78.184215         67.0     2787
# 4                71     0.01                7.097109         68.0     3013
# ...             ...      ...                     ...          ...      ...
# 2933             27     4.36                0.000000         68.0       31
# 2934             26     4.06                0.000000          7.0      998
# 2935             25     4.43                0.000000         73.0      304
# 2936             25     1.72                0.000000         76.0      529
# 2937             24     1.68                0.000000         79.0     1483
#
#       ...  Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  \
# 0     ...    6.0               8.16        65.0       0.1  584.259210
# 1     ...   58.0               8.18        62.0       0.1  612.696514
# 2     ...   62.0               8.13        64.0       0.1  631.744976
# 3     ...   67.0               8.52        67.0       0.1  669.959000
# 4     ...   68.0               7.87        68.0       0.1   63.537231
# ...   ...    ...                ...         ...       ...         ...
# 2933  ...   67.0               7.13        65.0      33.6  454.366654
# 2934  ...    7.0               6.52        68.0      36.7  453.351155
# 2935  ...   73.0               6.53        71.0      39.8   57.348340
# 2936  ...   76.0               6.16        75.0      42.1  548.587312
# 2937  ...   78.0               7.10        78.0      43.5  547.358878
#
#       Population  thinness  1-19 years  thinness 5-9 years  \
# 0     33736494.0                  17.2                17.3
# 1       327582.0                  17.5                17.5
# 2     31731688.0                  17.7                17.7
# 3      3696958.0                  17.9                18.0
# 4      2978599.0                  18.2                18.2
# ...          ...                   ...                 ...
# 2933  12777511.0                   9.4                 9.4
# 2934  12633897.0                   9.8                 9.9
# 2935    125525.0                   1.2                 1.3
# 2936  12366165.0                   1.6                 1.7
# 2937  12222251.0                  11.0                11.2
#
#       Income composition of resources  Schooling
# 0                               0.479       10.1
# 1                               0.476       10.0
# 2                               0.470        9.9
# 3                               0.463        9.8
# 4                               0.454        9.5
# ...                               ...        ...
# 2933                            0.407        9.2
# 2934                            0.418        9.5
# 2935                            0.427       10.0
# 2936                            0.427        9.8
# 2937                            0.434        9.8
#
# [2938 rows x 22 columns]

# %%
pd.set_option('display.max_columns',0)
df
# Out:
#           Country  Year      Status  ...  thinness 5-9 years  Income composition of resources  Schooling
# 0     Afghanistan  2015  Developing  ...                17.3                            0.479       10.1
# 1     Afghanistan  2014  Developing  ...                17.5                            0.476       10.0
# 2     Afghanistan  2013  Developing  ...                17.7                            0.470        9.9
# 3     Afghanistan  2012  Developing  ...                18.0                            0.463        9.8
# 4     Afghanistan  2011  Developing  ...                18.2                            0.454        9.5
# ...           ...   ...         ...  ...                 ...                              ...        ...
# 2933     Zimbabwe  2004  Developing  ...                 9.4                            0.407        9.2
# 2934     Zimbabwe  2003  Developing  ...                 9.9                            0.418        9.5
# 2935     Zimbabwe  2002  Developing  ...                 1.3                            0.427       10.0
# 2936     Zimbabwe  2001  Developing  ...                 1.7                            0.427        9.8
# 2937     Zimbabwe  2000  Developing  ...                11.2                            0.434        9.8
#
# [2938 rows x 22 columns]

# %% [markdown]
# ## EDA

# %%
df.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
miss.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# > Can't have null values for the target!

# %%
# drop null values ONLY FROM TARGET
df = df.dropna(subset=['Life expectancy'])

# %%
target = 'Life expectancy'

grid_spec = {'height_ratios':[0.8,0.2]}
fig, axes = plt.subplots(nrows=2, figsize=(6,5), gridspec_kw=grid_spec)

sns.histplot(data=df, x=target,ax=axes[0])
sns.boxplot(data=df, x=target, ax=axes[1]);

# %% [markdown]
# ## Preprocessing (with Sklearn v1.1+)

# %%
# Run the following command on your local computer to check the version of sklearn
import sklearn
# !python --version
print(f"sklearn version: {sklearn.__version__}")
# Out:
# Python 3.9.15
# sklearn version: 1.1.3

# %%
# ### Train Test Split
## Make x and y variables
target = "Life expectancy"
drop_feats = []

y = df[target].copy()
X = df.drop(columns=[target, *drop_feats]).copy()

## train-test-split with random state for reproducibility
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=SEED)
X_train.head(3)
# Out:
#           Country  Year      Status  ...  thinness 5-9 years  Income composition of resources  Schooling
# 2414  South Sudan  2010  Developing  ...                 NaN                            0.000        0.0
# 1576       Malawi  2009  Developing  ...                 6.8                            0.415        9.9
# 2559   Tajikistan  2009  Developing  ...                 3.8                            0.601       11.1
#
# [3 rows x 21 columns]

# %%
## Make numeric preprocessing pipeline
num_sel = make_column_selector(dtype_include='number')
num_pipe = make_pipeline(SimpleImputer(strategy='mean'))
num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer())])

# %%
## Make categorical preprocessing pipeline
cat_sel = make_column_selector(dtype_include='object')
cat_pipe = make_pipeline(SimpleImputer(strategy='constant',
                                       fill_value='MISSING'),
                         OneHotEncoder(handle_unknown='ignore', sparse=False))

# %%
## make the preprocessing column transformer
preprocessor = make_column_transformer((num_pipe, num_sel),
                                       (cat_pipe,cat_sel),)
preprocessor
# Out:
# ColumnTransformer(transformers=[('pipeline-1',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer())]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x0000012EF16B5F10>),
#                                 ('pipeline-2',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='MISSING',
#                                                                 strategy='constant')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x0000012EF1636700>)])

# %% [markdown]
# ### Make X_train_df and X_test_df, dataframe verisons of processed X_train/X_test.

# %%
preprocessor.fit(X_train)
X_train_df = pd.DataFrame(preprocessor.transform(X_train),
                          columns=preprocessor.get_feature_names_out(),
                         index=X_train.index)
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                          columns=preprocessor.get_feature_names_out(),
                         index=X_test.index)
display(X_train_df)
# Out:
#       pipeline-1__Year  pipeline-1__Adult Mortality  ...  pipeline-2__Status_Developed  pipeline-2__Status_Developing
# 2414            2010.0                        359.0  ...                           0.0                            1.0
# 1576            2009.0                        491.0  ...                           0.0                            1.0
# 2559            2009.0                        174.0  ...                           0.0                            1.0
# 1524            2013.0                        178.0  ...                           1.0                            0.0
# 33              2014.0                         11.0  ...                           0.0                            1.0
# ...                ...                          ...  ...                           ...                            ...
# 1427            2014.0                        199.0  ...                           0.0                            1.0
# 1838            2006.0                         71.0  ...                           1.0                            0.0
# 2857            2000.0                         18.0  ...                           0.0                            1.0
# 124             2003.0                         71.0  ...                           1.0                            0.0
# 2595            2005.0                         12.0  ...                           0.0                            1.0
#
# [2196 rows x 204 columns]

# %% [markdown]
# > #### Q: What's up with the feature names? What are we seeing?

# %% [markdown]
# ### Get Features Names + Verbose Feature Names Out

# %%
## make the preprocessing column transformer WITH CORRECT ARGS!
preprocessor = make_column_transformer((num_pipe, num_sel),
                                       (cat_pipe,cat_sel),
                                      verbose_feature_names_out=False)
preprocessor.fit(X_train)
X_train_df = pd.DataFrame(preprocessor.transform(X_train),
                          columns=preprocessor.get_feature_names_out(),
                         index=X_train.index)
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                          columns=preprocessor.get_feature_names_out(),
                         index=X_test.index)
display(X_train_df)
# Out:
#         Year  Adult Mortality  infant deaths  ...  Country_Zimbabwe  Status_Developed  Status_Developing
# 2414  2010.0            359.0           27.0  ...               0.0               0.0                1.0
# 1576  2009.0            491.0           36.0  ...               0.0               0.0                1.0
# 2559  2009.0            174.0           10.0  ...               0.0               0.0                1.0
# 1524  2013.0            178.0            0.0  ...               0.0               1.0                0.0
# 33    2014.0             11.0           21.0  ...               0.0               0.0                1.0
# ...      ...              ...            ...  ...               ...               ...                ...
# 1427  2014.0            199.0            8.0  ...               0.0               0.0                1.0
# 1838  2006.0             71.0            1.0  ...               0.0               1.0                0.0
# 2857  2000.0             18.0            0.0  ...               0.0               0.0                1.0
# 124   2003.0             71.0            1.0  ...               0.0               1.0                0.0
# 2595  2005.0             12.0            0.0  ...               0.0               0.0                1.0
#
# [2196 rows x 204 columns]

# %% [markdown]
# # Modeling - Linear Regression

# %%
def evaluate_regression(model, X_train,y_train, X_test, y_test,for_slides=True): 
    """Evaluates a scikit learn regression model using r-squared and RMSE
    FOR SLIDES VERS DOES MULTIPLE PRINT STATEMENTS FOR VERTICAL DISPLAY OF INFO"""
    
    ## Training Data
    y_pred_train = model.predict(X_train)
    r2_train = metrics.r2_score(y_train, y_pred_train)
    rmse_train = metrics.mean_squared_error(y_train, y_pred_train, 
                                            squared=False)
    mae_train = metrics.mean_absolute_error(y_train, y_pred_train)
    

    ## Test Data
    y_pred_test = model.predict(X_test)
    r2_test = metrics.r2_score(y_test, y_pred_test)
    rmse_test = metrics.mean_squared_error(y_test, y_pred_test, 
                                            squared=False)
    mae_test = metrics.mean_absolute_error(y_test, y_pred_test)
    
    if for_slides:
        df_version =[['Split','R^2','MAE','RMSE']]
        df_version.append(['Train',r2_train, mae_train, rmse_train])
        df_version.append(['Test',r2_test, mae_test, rmse_test])
        df_results = pd.DataFrame(df_version[1:], columns=df_version[0])
        df_results = df_results.round(2)
        display(df_results.style.hide(axis='index').format(precision=2, thousands=','))
        
    else: 
        print(f"Training Data:\tR^2 = {r2_train:,.2f}\tRMSE = {rmse_train:,.2f}\tMAE = {mae_train:,.2f}")
        print(f"Test Data:\tR^2 = {r2_test:,.2f}\tRMSE = {rmse_test:,.2f}\tMAE = {mae_test:,.2f}")

# %% [markdown]
# ## Model 1: Baseline LinReg

# %%
from sklearn.linear_model import LinearRegression
lin_reg= LinearRegression()
lin_reg.fit(X_train_df,y_train)
evaluate_regression(lin_reg, X_train_df, y_train, 
                    X_test_df, y_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_68724">
#   <thead>
#     <tr>
#       <th id="T_68724_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_68724_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_68724_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_68724_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_68724_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_68724_row0_col1" class="data row0 col1" >0.96</td>
#       <td id="T_68724_row0_col2" class="data row0 col2" >1.14</td>
#       <td id="T_68724_row0_col3" class="data row0 col3" >1.83</td>
#     </tr>
#     <tr>
#       <td id="T_68724_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_68724_row1_col1" class="data row1 col1" >0.96</td>
#       <td id="T_68724_row1_col2" class="data row1 col2" >1.20</td>
#       <td id="T_68724_row1_col3" class="data row1 col3" >1.88</td>
#     </tr>
#   </tbody>
# </table>

# %%
de.plot_residuals(lin_reg, X_test_df,y_test)

# %% [markdown]
# ### Extracting and Visualizing Coefficients

# %% [markdown]
# #### Extracting Coefficients

# %%
# access the .coef_ 
lin_reg.coef_

# %%
# Intercept
lin_reg.intercept_

# %%
## Saving the coefficients
coeffs = pd.Series(lin_reg.coef_, index= lin_reg.feature_names_in_)
coeffs.loc['intercept'] = lin_reg.intercept_
coeffs

# %% [markdown]
# #### def `get_coefficients`

# %%
def get_coefficients(lin_reg):
    coeffs = pd.Series(lin_reg.coef_, index= lin_reg.feature_names_in_)
    coeffs.loc['intercept'] = lin_reg.intercept_
    return coeffs

# %%
coeffs = get_coefficients(lin_reg)
coeffs
# Out:
# Year                        0.265644
# Adult Mortality            -0.002424
# infant deaths               0.109358
# Alcohol                    -0.064367
# percentage expenditure      0.000154
#                              ...
# Country_Zambia             -9.018217
# Country_Zimbabwe           -8.385612
# Status_Developed            5.307119
# Status_Developing          -5.307128
# intercept                -461.245533
# Length: 205, dtype: float64

# %%
## formatting numbers to not use , thousands sep, and 4 digits floats
pd.set_option('display.float_format',lambda x: f"{x:,.4f}")
pd.set_option('display.max_rows', None)

# %%
coeffs.sort_values()
# Out:
# intercept                                                      -461.2455
# Country_Sierra Leone                                            -19.3439
# Country_Côte d'Ivoire                                           -15.4878
# Country_Central African Republic                                -15.2399
# Country_Angola                                                  -15.2160
# Country_Chad                                                    -13.7055
# Country_Somalia                                                 -12.4401
# Country_Malawi                                                  -11.4993
# Country_Lesotho                                                 -11.3403
# Country_Guinea-Bissau                                           -10.5861
# Country_South Sudan                                             -10.5449
# Country_Burundi                                                 -10.4404
# Country_Cameroon                                                -10.1861
# Country_Guinea                                                  -10.1712
# Country_Democratic Republic of the Congo                        -10.1366
# Country_Mali                                                     -9.9653
# Country_Equatorial Guinea                                        -9.7840
# Country_Togo                                                     -9.7698
# Country_Mozambique                                               -9.7641
# Country_Benin                                                    -9.2593
# Country_Afghanistan                                              -9.1717
# Country_Burkina Faso                                             -9.1021
# Country_Zambia                                                   -9.0182
# Country_Liberia                                                  -8.9318
# Country_Zimbabwe                                                 -8.3856
# Country_United Republic of Tanzania                              -7.7254
# Country_Gambia                                                   -7.5350
# Country_Congo                                                    -7.4814
# Country_Niger                                                    -7.3244
# Country_Rwanda                                                   -7.2113
# Country_Uganda                                                   -7.0310
# Country_Eritrea                                                  -6.6634
# Country_Kenya                                                    -6.5444
# Country_Haiti                                                    -6.4665
# Country_Comoros                                                  -6.2642
# Country_Botswana                                                 -6.1271
# Country_Romania                                                  -6.0393
# Country_Lithuania                                                -6.0133
# Country_Pakistan                                                 -5.9946
# Country_Ghana                                                    -5.6855
# Country_Swaziland                                                -5.6651
# Country_Bulgaria                                                 -5.5721
# Status_Developing                                                -5.3071
# Country_Papua New Guinea                                         -5.2930
# Country_Lao People's Democratic Republic                         -5.1727
# Country_Djibouti                                                 -4.9420
# Country_Hungary                                                  -4.8169
# Country_Mauritania                                               -4.7685
# Country_Latvia                                                   -4.5692
# Country_Senegal                                                  -4.4294
# Country_Sudan                                                    -4.3962
# Country_Madagascar                                               -4.2632
# Country_India                                                    -4.0935
# Country_South Africa                                             -4.0866
# Country_Myanmar                                                  -3.9183
# Country_Ethiopia                                                 -3.8403
# Country_Timor-Leste                                              -3.7631
# Country_Cambodia                                                 -3.7429
# Country_Slovakia                                                 -3.7338
# Country_Yemen                                                    -3.6776
# Country_Turkmenistan                                             -3.2145
# Country_Poland                                                   -3.1889
# Country_Namibia                                                  -3.1133
# Country_Kiribati                                                 -3.0362
# Country_Croatia                                                  -2.6742
# Country_Sao Tome and Principe                                    -2.6345
# Country_Gabon                                                    -2.6268
# Country_Bhutan                                                   -2.4620
# Country_Mongolia                                                 -2.2746
# Country_Nepal                                                    -2.1496
# Country_Indonesia                                                -1.9754
# Country_Nigeria                                                  -1.8029
# Country_Guyana                                                   -1.7270
# Country_Tajikistan                                               -1.5385
# Country_Czechia                                                  -1.3900
# Country_Kazakhstan                                               -1.3704
# Country_Philippines                                              -0.5655
# Country_United States of America                                 -0.4879
# Country_Uzbekistan                                               -0.4015
# Country_Bolivia (Plurinational State of)                         -0.3605
# HIV/AIDS                                                         -0.3205
# Country_Russian Federation                                       -0.2607
# Income composition of resources                                  -0.2243
# under-five deaths                                                -0.0826
# Alcohol                                                          -0.0644
# Total expenditure                                                -0.0239
# Country_Slovenia                                                 -0.0211
# Hepatitis B                                                      -0.0046
# BMI                                                              -0.0026
# Adult Mortality                                                  -0.0024
# GDP                                                              -0.0000
# Measles                                                          -0.0000
# Population                                                        0.0000
# percentage expenditure                                            0.0002
# Diphtheria                                                        0.0049
# Country_Denmark                                                   0.0056
# Polio                                                             0.0057
# Country_Solomon Islands                                           0.0109
# thinness 5-9 years                                                0.0162
# thinness  1-19 years                                              0.0256
# Country_Fiji                                                      0.0739
# infant deaths                                                     0.1094
# Schooling                                                         0.1463
# Year                                                              0.2656
# Country_Micronesia (Federated States of)                          0.5334
# Country_Bangladesh                                                0.8295
# Country_Belgium                                                   1.0001
# Country_Cyprus                                                    1.0020
# Country_Kyrgyzstan                                                1.1735
# Country_Democratic People's Republic of Korea                     1.1787
# Country_Ireland                                                   1.3642
# Country_Belize                                                    1.3909
# Country_Portugal                                                  1.4045
# Country_New Zealand                                               1.5795
# Country_Germany                                                   1.6910
# Country_Malta                                                     1.7526
# Country_Ukraine                                                   1.8411
# Country_Netherlands                                               1.8682
# Country_Belarus                                                   2.0765
# Country_Norway                                                    2.1011
# Country_Syrian Arab Republic                                      2.1099
# Country_Luxembourg                                                2.1540
# Country_Australia                                                 2.2835
# Country_Sweden                                                    2.3242
# Country_Singapore                                                 2.3691
# Country_Suriname                                                  2.4562
# Country_United Kingdom of Great Britain and Northern Ireland      2.4744
# Country_Switzerland                                               2.6197
# Country_Azerbaijan                                                2.6223
# Country_Iraq                                                      2.6481
# Country_Republic of Moldova                                       2.7691
# Country_Egypt                                                     2.8309
# Country_Iceland                                                   2.9603
# Country_Libya                                                     3.0206
# Country_Austria                                                   3.0797
# Country_Trinidad and Tobago                                       3.1004
# Country_China                                                     3.1433
# Country_Spain                                                     3.2163
# Country_Italy                                                     3.2607
# Country_Japan                                                     3.3030
# Country_Vanuatu                                                   3.5317
# Country_El Salvador                                               3.5775
# Country_Morocco                                                   3.6025
# Country_Sri Lanka                                                 3.9134
# Country_Brazil                                                    3.9213
# Country_Mauritius                                                 4.1302
# Country_Guatemala                                                 4.2767
# Country_Jordan                                                    4.2884
# Country_Tonga                                                     4.3100
# Country_Saudi Arabia                                              4.3625
# Country_Seychelles                                                4.4281
# Country_Cabo Verde                                                4.5222
# Country_Thailand                                                  4.5424
# Country_Algeria                                                   4.5999
# Country_Paraguay                                                  4.6176
# Country_Iran (Islamic Republic of)                                4.7422
# Country_Grenada                                                   4.8194
# Country_Nicaragua                                                 4.9773
# Country_Colombia                                                  4.9792
# Country_Dominican Republic                                        5.0158
# Country_Saint Vincent and the Grenadines                          5.0846
# Country_Turkey                                                    5.1796
# Country_Malaysia                                                  5.1907
# Country_Honduras                                                  5.2252
# Country_Armenia                                                   5.2406
# Status_Developed                                                  5.3071
# Country_Peru                                                      5.4266
# Country_Venezuela (Bolivarian Republic of)                        5.4748
# Country_Kuwait                                                    5.5087
# Country_Tunisia                                                   5.5193
# Country_Georgia                                                   5.5514
# Country_Lebanon                                                   5.5826
# Country_The former Yugoslav republic of Macedonia                 5.6843
# Country_Serbia                                                    5.9160
# Country_Viet Nam                                                  5.9871
# Country_Saint Lucia                                               6.0359
# Country_Barbados                                                  6.0630
# Country_Oman                                                      6.0924
# Country_Samoa                                                     6.1060
# Country_Maldives                                                  6.2194
# Country_Montenegro                                                6.2765
# Country_Argentina                                                 6.3523
# Country_Jamaica                                                   6.4010
# Country_Ecuador                                                   6.5222
# Country_Bahamas                                                   6.6436
# Country_Estonia                                                   6.7086
# Country_Albania                                                   6.7894
# Country_Bahrain                                                   6.8303
# Country_Mexico                                                    7.0508
# Country_United Arab Emirates                                      7.1877
# Country_Brunei Darussalam                                         7.4862
# Country_Antigua and Barbuda                                       7.5314
# Country_Bosnia and Herzegovina                                    7.6179
# Country_Uruguay                                                   7.8886
# Country_Panama                                                    8.5552
# Country_Qatar                                                     8.7526
# Country_Cuba                                                      9.0039
# Country_Costa Rica                                               10.2361
# Country_Chile                                                    10.9669
# Country_Finland                                                  11.8384
# Country_Republic of Korea                                        12.7644
# Country_Israel                                                   12.7908
# Country_Canada                                                   13.1336
# Country_France                                                   13.1650
# Country_Greece                                                   13.2538
# dtype: float64

# %% [markdown]
# ### Visualizing

# %% [markdown]
# #### **Q: How can we handle this many coefficients in our viz?**
#
# - Some options include:
#     - Only plot most the N most positive and N most negative.
#     - Separate out OHE countries into a separate graph.
#
#
# - Let's try the second option: separating the OHE countries.

# %%
## Get a list of all of the ohe columsn
country_feats = [c for c in X_train_df.columns if c.startswith('Country')]
len(country_feats)
# Out:
# 183

# %%
## Plot country ceoffs
ax = coeffs[country_feats].sort_values().plot(kind='barh', figsize=(8,26))
ax.axvline(0, color='k')
ax.set(xlabel='Life Expectancy', title="Coefficients - Countries");

# %%
## Plot everything but countries
ax = coeffs.drop(country_feats).sort_values().plot(kind='barh')#, figsize=(8,26))
ax.axvline(0)
ax.set(xlabel='Life Expectancy', title="Coefficients - Without Countries");

# %% [markdown]
# > ***Q: What do we notice about our non-country coefficients? Is there anything odd that would be difficult to a stakeholder?***

# %% [markdown]
# - What would we get if we didn't include an intercept?

# %% [markdown]
# ## Model #2 - No Intercept

# %%
lin_reg_noint= LinearRegression(fit_intercept=False)
lin_reg_noint.fit(X_train_df,y_train)
evaluate_regression(lin_reg_noint, X_train_df, y_train, 
                    X_test_df, y_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_5e96f">
#   <thead>
#     <tr>
#       <th id="T_5e96f_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_5e96f_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_5e96f_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_5e96f_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_5e96f_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_5e96f_row0_col1" class="data row0 col1" >0.96</td>
#       <td id="T_5e96f_row0_col2" class="data row0 col2" >1.14</td>
#       <td id="T_5e96f_row0_col3" class="data row0 col3" >1.83</td>
#     </tr>
#     <tr>
#       <td id="T_5e96f_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_5e96f_row1_col1" class="data row1 col1" >0.96</td>
#       <td id="T_5e96f_row1_col2" class="data row1 col2" >1.20</td>
#       <td id="T_5e96f_row1_col3" class="data row1 col3" >1.88</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# > Notice the model's performance is the same

# %%
de.plot_residuals(lin_reg_noint, X_test_df,y_test)

# %%
coeffs_noint = get_coefficients(lin_reg_noint)
coeffs_noint
# Out:
# Year                                                                 0.2656
# Adult Mortality                                                     -0.0024
# infant deaths                                                        0.1094
# Alcohol                                                             -0.0644
# percentage expenditure                                               0.0002
# Hepatitis B                                                         -0.0046
# Measles                                                             -0.0000
# BMI                                                                 -0.0026
# under-five deaths                                                   -0.0827
# Polio                                                                0.0057
# Total expenditure                                                   -0.0238
# Diphtheria                                                           0.0049
# HIV/AIDS                                                            -0.3204
# GDP                                                                 -0.0000
# Population                                                           0.0000
# thinness  1-19 years                                                 0.0260
# thinness 5-9 years                                                   0.0154
# Income composition of resources                                     -0.2345
# Schooling                                                            0.1471
# Country_Afghanistan                                            -16,031.9349
# Country_Albania                                                -16,016.0098
# Country_Algeria                                                -16,018.0768
# Country_Angola                                                 -16,037.9980
# Country_Antigua and Barbuda                                    -16,015.2396
# Country_Argentina                                              -16,016.3813
# Country_Armenia                                                -16,017.5818
# Country_Australia                                               46,659.3188
# Country_Austria                                                 46,660.2762
# Country_Azerbaijan                                             -16,020.2227
# Country_Bahamas                                                -16,016.1229
# Country_Bahrain                                                -16,015.9540
# Country_Bangladesh                                             -16,022.0326
# Country_Barbados                                               -16,016.7295
# Country_Belarus                                                -16,020.7554
# Country_Belgium                                                 46,658.1191
# Country_Belize                                                 -16,021.3498
# Country_Benin                                                  -16,032.0182
# Country_Bhutan                                                 -16,025.3413
# Country_Bolivia (Plurinational State of)                       -16,023.1087
# Country_Bosnia and Herzegovina                                 -16,015.1728
# Country_Botswana                                               -16,028.9376
# Country_Brazil                                                 -16,018.8767
# Country_Brunei Darussalam                                      -16,015.2226
# Country_Bulgaria                                                46,651.5814
# Country_Burkina Faso                                           -16,031.7900
# Country_Burundi                                                -16,033.2001
# Country_Cabo Verde                                             -16,018.2693
# Country_Cambodia                                               -16,026.4305
# Country_Cameroon                                               -16,032.9936
# Country_Canada                                                 -16,009.6435
# Country_Central African Republic                               -16,038.0396
# Country_Chad                                                   -16,036.5101
# Country_Chile                                                  -16,011.7785
# Country_China                                                  -16,019.6241
# Country_Colombia                                               -16,017.7634
# Country_Comoros                                                -16,028.9935
# Country_Congo                                                  -16,030.3225
# Country_Costa Rica                                             -16,012.5245
# Country_Croatia                                                 46,654.3975
# Country_Cuba                                                   -16,013.7980
# Country_Cyprus                                                  46,658.0740
# Country_Czechia                                                 46,655.9259
# Country_Côte d'Ivoire                                          -16,038.2908
# Country_Democratic People's Republic of Korea                  -16,021.6383
# Country_Democratic Republic of the Congo                       -16,032.9240
# Country_Denmark                                                 46,657.1308
# Country_Djibouti                                               -16,027.7390
# Country_Dominican Republic                                     -16,017.7678
# Country_Ecuador                                                -16,016.3283
# Country_Egypt                                                  -16,019.9633
# Country_El Salvador                                            -16,019.2296
# Country_Equatorial Guinea                                      -16,032.6231
# Country_Eritrea                                                -16,029.4705
# Country_Estonia                                                -16,016.1299
# Country_Ethiopia                                               -16,026.6755
# Country_Fiji                                                   -16,022.6539
# Country_Finland                                                -16,010.8399
# Country_France                                                 -16,009.6049
# Country_Gabon                                                  -16,025.4080
# Country_Gambia                                                 -16,030.3181
# Country_Georgia                                                -16,017.2152
# Country_Germany                                                 46,658.9091
# Country_Ghana                                                  -16,028.4417
# Country_Greece                                                 -16,009.4861
# Country_Grenada                                                -16,017.9486
# Country_Guatemala                                              -16,018.5320
# Country_Guinea                                                 -16,032.9673
# Country_Guinea-Bissau                                          -16,033.4386
# Country_Guyana                                                 -16,024.5094
# Country_Haiti                                                  -16,029.2465
# Country_Honduras                                               -16,017.5506
# Country_Hungary                                                 46,652.3171
# Country_Iceland                                                 46,660.0017
# Country_India                                                  -16,026.8841
# Country_Indonesia                                              -16,024.8046
# Country_Iran (Islamic Republic of)                             -16,018.0058
# Country_Iraq                                                   -16,020.1102
# Country_Ireland                                                 46,658.6211
# Country_Israel                                                 -16,009.9527
# Country_Italy                                                   46,660.4727
# Country_Jamaica                                                -16,016.4495
# Country_Japan                                                   46,660.5048
# Country_Jordan                                                 -16,018.5021
# Country_Kazakhstan                                             -16,024.1846
# Country_Kenya                                                  -16,029.3147
# Country_Kiribati                                               -16,025.7991
# Country_Kuwait                                                 -16,017.2855
# Country_Kyrgyzstan                                             -16,021.6369
# Country_Lao People's Democratic Republic                       -16,027.9403
# Country_Latvia                                                  46,652.5589
# Country_Lebanon                                                -16,017.1968
# Country_Lesotho                                                -16,034.0358
# Country_Liberia                                                -16,031.7135
# Country_Libya                                                  -16,019.8184
# Country_Lithuania                                               46,651.1027
# Country_Luxembourg                                              46,659.2334
# Country_Madagascar                                             -16,027.0503
# Country_Malawi                                                 -16,034.3370
# Country_Malaysia                                               -16,017.5650
# Country_Maldives                                               -16,016.5240
# Country_Mali                                                   -16,032.7375
# Country_Malta                                                   46,658.9109
# Country_Mauritania                                             -16,027.5216
# Country_Mauritius                                              -16,018.6610
# Country_Mexico                                                 -16,015.7353
# Country_Micronesia (Federated States of)                       -16,022.2231
# Country_Mongolia                                               -16,025.0453
# Country_Montenegro                                             -16,016.5090
# Country_Morocco                                                -16,019.1915
# Country_Mozambique                                             -16,032.5209
# Country_Myanmar                                                -16,026.6690
# Country_Namibia                                                -16,025.8846
# Country_Nepal                                                  -16,024.9570
# Country_Netherlands                                             46,659.0124
# Country_New Zealand                                             46,658.7020
# Country_Nicaragua                                              -16,017.7777
# Country_Niger                                                  -16,030.1118
# Country_Nigeria                                                -16,024.5798
# Country_Norway                                                  46,659.2726
# Country_Oman                                                   -16,016.6555
# Country_Pakistan                                               -16,028.7456
# Country_Panama                                                 -16,014.3366
# Country_Papua New Guinea                                       -16,028.0599
# Country_Paraguay                                               -16,018.1662
# Country_Peru                                                   -16,017.4681
# Country_Philippines                                            -16,023.3303
# Country_Poland                                                  46,653.9471
# Country_Portugal                                                46,658.5765
# Country_Qatar                                                  -16,014.0654
# Country_Republic of Korea                                      -16,010.0849
# Country_Republic of Moldova                                    -16,020.0136
# Country_Romania                                                 46,651.1325
# Country_Russian Federation                                     -16,023.0454
# Country_Rwanda                                                 -16,030.0666
# Country_Saint Lucia                                            -16,016.8411
# Country_Saint Vincent and the Grenadines                       -16,017.6743
# Country_Samoa                                                  -16,016.6966
# Country_Sao Tome and Principe                                  -16,025.4063
# Country_Saudi Arabia                                           -16,018.3921
# Country_Senegal                                                -16,027.2179
# Country_Serbia                                                 -16,016.9316
# Country_Seychelles                                             -16,018.4449
# Country_Sierra Leone                                           -16,042.1568
# Country_Singapore                                               46,659.4422
# Country_Slovakia                                                46,653.4068
# Country_Slovenia                                                46,657.1499
# Country_Solomon Islands                                        -16,022.7968
# Country_Somalia                                                -16,035.1872
# Country_South Africa                                           -16,026.8507
# Country_South Sudan                                            -16,033.3177
# Country_Spain                                                   46,660.4838
# Country_Sri Lanka                                              -16,018.8698
# Country_Sudan                                                  -16,027.1255
# Country_Suriname                                               -16,020.2761
# Country_Swaziland                                              -16,028.4861
# Country_Sweden                                                  46,659.4443
# Country_Switzerland                                             46,659.7928
# Country_Syrian Arab Republic                                   -16,020.6325
# Country_Tajikistan                                             -16,024.3654
# Country_Thailand                                               -16,018.1205
# Country_The former Yugoslav republic of Macedonia              -16,017.1166
# Country_Timor-Leste                                            -16,026.5570
# Country_Togo                                                   -16,032.5085
# Country_Tonga                                                  -16,018.4730
# Country_Trinidad and Tobago                                    -16,019.6658
# Country_Tunisia                                                -16,017.3156
# Country_Turkey                                                 -16,017.5838
# Country_Turkmenistan                                           -16,025.9662
# Country_Uganda                                                 -16,029.8266
# Country_Ukraine                                                -16,020.9641
# Country_United Arab Emirates                                   -16,015.5887
# Country_United Kingdom of Great Britain and Northern Ireland    46,659.6425
# Country_United Republic of Tanzania                            -16,030.4731
# Country_United States of America                                46,656.6241
# Country_Uruguay                                                -16,014.8921
# Country_Uzbekistan                                             -16,023.1605
# Country_Vanuatu                                                -16,019.2495
# Country_Venezuela (Bolivarian Republic of)                     -16,017.3046
# Country_Viet Nam                                               -16,016.7812
# Country_Yemen                                                  -16,026.5476
# Country_Zambia                                                 -16,031.8093
# Country_Zimbabwe                                               -16,031.1363
# Status_Developed                                               -47,113.0867
# Status_Developing                                               15,556.2302
# intercept                                                            0.0000
# dtype: float64

# %% [markdown]
# > But coefficients have changed

# %%
ax = coeffs_noint[country_feats].sort_values().plot(kind='barh', figsize=(8,26))
ax.axvline(0)
ax.set(xlabel='Life Expectancy', title="Coefficients - Countries");

# %%
ax = coeffs_noint.drop(country_feats).sort_values().plot(kind='barh')#, figsize=(8,26))
ax.axvline(0)
ax.set(xlabel='Life Expectancy', title="Coefficients - Without Countries");

# %% [markdown]
# ## Model #3 - No Countries

# %%
# ### Train Test Split
## Make x and y variables
target = "Life expectancy"
drop_feats = ["Country"]

y = df[target].copy()
X = df.drop(columns=[target, *drop_feats]).copy()

## train-test-split with random state for reproducibility
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=SEED)

## Make numeric preprocessing pipeline
num_sel = make_column_selector(dtype_include='number')
num_pipe = make_pipeline(SimpleImputer(strategy='mean'))


## Make categorical preprocessing pipeline
cat_sel = make_column_selector(dtype_include='object')
cat_pipe = make_pipeline(SimpleImputer(strategy='constant',
                                       fill_value='MISSING'),
                         OneHotEncoder(handle_unknown='ignore', sparse=False))

# %%
preprocessor.fit(X_train)
feature_names = preprocessor.get_feature_names_out()
X_train_df = pd.DataFrame(preprocessor.transform(X_train),
                          columns=feature_names,
                         index=X_train.index)
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                          columns=feature_names,
                         index=X_test.index)

# %%
lin_reg= LinearRegression(fit_intercept=False)
lin_reg.fit(X_train_df,y_train)
evaluate_regression(lin_reg, X_train_df, y_train, 
                    X_test_df, y_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_4e558">
#   <thead>
#     <tr>
#       <th id="T_4e558_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_4e558_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_4e558_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_4e558_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4e558_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_4e558_row0_col1" class="data row0 col1" >0.82</td>
#       <td id="T_4e558_row0_col2" class="data row0 col2" >3.00</td>
#       <td id="T_4e558_row0_col3" class="data row0 col3" >4.02</td>
#     </tr>
#     <tr>
#       <td id="T_4e558_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_4e558_row1_col1" class="data row1 col1" >0.82</td>
#       <td id="T_4e558_row1_col2" class="data row1 col2" >3.06</td>
#       <td id="T_4e558_row1_col3" class="data row1 col3" >4.12</td>
#     </tr>
#   </tbody>
# </table>

# %%
de.plot_residuals(lin_reg, X_test_df,y_test)

# %%
coeffs = get_coefficients(lin_reg)
coeffs
# Out:
# Year                              -0.0168
# Adult Mortality                   -0.0193
# infant deaths                      0.1070
# Alcohol                            0.0556
# percentage expenditure             0.0000
# Hepatitis B                       -0.0096
# Measles                           -0.0000
# BMI                                0.0391
# under-five deaths                 -0.0810
# Polio                              0.0250
# Total expenditure                  0.1062
# Diphtheria                         0.0377
# HIV/AIDS                          -0.4789
# GDP                                0.0000
# Population                         0.0000
# thinness  1-19 years              -0.0498
# thinness 5-9 years                -0.0265
# Income composition of resources    5.7370
# Schooling                          0.6857
# Status_Developed                  89.6930
# Status_Developing                 88.2086
# intercept                          0.0000
# dtype: float64

# %%
coeffs.sort_values().plot(kind='barh')
# Out:
# <Axes: >

# %% [markdown]
# ## Model 3: Dropping Categories with OneHotEncoder

# %% [markdown]
# ####  OneHotEncoder's Drop Argument

# %%
## make pipelines for categorical vs numeric data
cat_pipe = make_pipeline(SimpleImputer(strategy='constant',
                                       fill_value='MISSING'),
                         OneHotEncoder(drop='if_binary', sparse=False,
                                      ))
cat_pipe
# Out:
# Pipeline(steps=[('simpleimputer',
#                  SimpleImputer(fill_value='MISSING', strategy='constant')),
#                 ('onehotencoder',
#                  OneHotEncoder(drop='if_binary', sparse=False))])

# %%
num_pipe = make_pipeline(SimpleImputer(strategy='mean'))

## make the preprocessing column transformer
preprocessor = make_column_transformer((num_pipe, num_sel),
                                       (cat_pipe,cat_sel),
                                      verbose_feature_names_out=False)
preprocessor

preprocessor.fit(X_train)
feature_names = preprocessor.get_feature_names_out()

X_train_df = pd.DataFrame(preprocessor.transform(X_train),
                          columns=feature_names,
                         index=X_train.index)
X_test_df = pd.DataFrame(preprocessor.transform(X_test),
                          columns=feature_names,
                         index=X_test.index)
display(X_train_df.head())
# Out:
#            Year  Adult Mortality  infant deaths  ...  Income composition of resources  Schooling  Status_Developing
# 2414 2,010.0000         359.0000        27.0000  ...                           0.0000     0.0000             1.0000
# 1576 2,009.0000         491.0000        36.0000  ...                           0.4150     9.9000             1.0000
# 2559 2,009.0000         174.0000        10.0000  ...                           0.6010    11.1000             1.0000
# 1524 2,013.0000         178.0000         0.0000  ...                           0.8340    16.4000             0.0000
# 33   2,014.0000          11.0000        21.0000  ...                           0.7410    14.4000             1.0000
#
# [5 rows x 20 columns]

# %%
lin_reg_drop = LinearRegression(fit_intercept=False)
lin_reg_drop.fit(X_train_df,y_train)
evaluate_regression(lin_reg_drop, X_train_df, y_train, 
                    X_test_df, y_test)

de.plot_residuals(lin_reg_drop, X_test_df,y_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_ef240">
#   <thead>
#     <tr>
#       <th id="T_ef240_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_ef240_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_ef240_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_ef240_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ef240_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_ef240_row0_col1" class="data row0 col1" >0.82</td>
#       <td id="T_ef240_row0_col2" class="data row0 col2" >3.01</td>
#       <td id="T_ef240_row0_col3" class="data row0 col3" >4.03</td>
#     </tr>
#     <tr>
#       <td id="T_ef240_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_ef240_row1_col1" class="data row1 col1" >0.82</td>
#       <td id="T_ef240_row1_col2" class="data row1 col2" >3.05</td>
#       <td id="T_ef240_row1_col3" class="data row1 col3" >4.12</td>
#     </tr>
#   </tbody>
# </table>

# %%
coeffs_dropped = get_coefficients(lin_reg_drop)


ax = coeffs_dropped.sort_values().plot(kind='barh')#, figsize=(8,26))
ax.axvline(0)
ax.set(xlabel='Life Expectancy', title="Coefficients - Without Countries");

# %% [markdown]
# > ***Q: What are the most positive coefficients? What are the most negative?***
#
# - Why does infant_deaths have a positive coefficient??

# %%
plot_df = pd.concat([X_train_df,y_train],axis=1)

# %%
sns.scatterplot(data=plot_df, x='infant deaths', y=target)
# Out:
# <Axes: xlabel='infant deaths', ylabel='Life expectancy'>

# %%
regplot_kws = dict(line_kws={'color':'red'},
                  scatter_kws={'ec':'white','lw':0.5})
sns.regplot(data=plot_df, x='infant deaths', y=target,**regplot_kws)
# Out:
# <Axes: xlabel='infant deaths', ylabel='Life expectancy'>

# %%
sns.regplot(data=plot_df, x='infant deaths', y=target,**regplot_kws,
           lowess=True)
# Out:
# <Axes: xlabel='infant deaths', ylabel='Life expectancy'>

# %% [markdown]
# > Feature is too complex for a simple linear regression. Let's try a random forest.

# %% [markdown]
# # BOOKMARK

# %% [markdown]
# ## Feature Importance

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf_reg = RandomForestRegressor()
rf_reg.fit(X_train_df,y_train)
evaluate_regression(rf_reg, X_train_df, y_train, 
                    X_test_df, y_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_82c35">
#   <thead>
#     <tr>
#       <th id="T_82c35_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_82c35_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_82c35_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_82c35_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_82c35_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_82c35_row0_col1" class="data row0 col1" >0.99</td>
#       <td id="T_82c35_row0_col2" class="data row0 col2" >0.45</td>
#       <td id="T_82c35_row0_col3" class="data row0 col3" >0.71</td>
#     </tr>
#     <tr>
#       <td id="T_82c35_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_82c35_row1_col1" class="data row1 col1" >0.97</td>
#       <td id="T_82c35_row1_col2" class="data row1 col2" >1.11</td>
#       <td id="T_82c35_row1_col3" class="data row1 col3" >1.75</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# > Using the models .feature_names_in_

# %%
# Extract Feature Importances
importances = pd.Series(rf_reg.feature_importances_, index= rf_reg.feature_names_in_)
importances
# Out:
# Year                              0.0076
# Adult Mortality                   0.1251
# infant deaths                     0.0070
# Alcohol                           0.0065
# percentage expenditure            0.0035
# Hepatitis B                       0.0024
# Measles                           0.0028
# BMI                               0.0114
# under-five deaths                 0.0151
# Polio                             0.0040
# Total expenditure                 0.0060
# Diphtheria                        0.0044
# HIV/AIDS                          0.5991
# GDP                               0.0042
# Population                        0.0032
# thinness  1-19 years              0.0059
# thinness 5-9 years                0.0096
# Income composition of resources   0.1636
# Schooling                         0.0185
# Status_Developing                 0.0001
# dtype: float64

# %%
# create a function to extract importances
def get_importances(rf_reg):
    importances = pd.Series(rf_reg.feature_importances_, index= rf_reg.feature_names_in_)
    return importances

importances = get_importances(rf_reg)
importances

# %%
# Plot Importances
ax = importances.sort_values().tail(20).plot(kind='barh')#,figsize=(6,4))
ax.axvline(0, color='k')
ax.set(title='Feature Importance - Decision Tree Regressor',ylabel="Feature Name",
      xlabel='Importance');

# %% [markdown]
# ## Using joblib to Save our Model, Data, and Objects

# %%
X_train.head()
# Out:
#       Year      Status  Adult Mortality  ...  thinness 5-9 years  Income composition of resources  Schooling
# 2414  2010  Developing         359.0000  ...                 NaN                           0.0000     0.0000
# 1576  2009  Developing         491.0000  ...              6.8000                           0.4150     9.9000
# 2559  2009  Developing         174.0000  ...              3.8000                           0.6010    11.1000
# 1524  2013   Developed         178.0000  ...              2.7000                           0.8340    16.4000
# 33    2014  Developing          11.0000  ...              5.8000                           0.7410    14.4000
#
# [5 rows x 20 columns]

# %%
evaluate_regression(lin_reg_drop,X_train_df,y_train, X_test_df, y_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_92407">
#   <thead>
#     <tr>
#       <th id="T_92407_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_92407_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_92407_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_92407_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_92407_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_92407_row0_col1" class="data row0 col1" >0.82</td>
#       <td id="T_92407_row0_col2" class="data row0 col2" >3.01</td>
#       <td id="T_92407_row0_col3" class="data row0 col3" >4.03</td>
#     </tr>
#     <tr>
#       <td id="T_92407_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_92407_row1_col1" class="data row1 col1" >0.82</td>
#       <td id="T_92407_row1_col2" class="data row1 col2" >3.05</td>
#       <td id="T_92407_row1_col3" class="data row1 col3" >4.12</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluate_regression(rf_reg,X_train_df,y_train, X_test_df, y_test)
# Out:
# <style type="text/css">
# </style>
# <table id="T_83e50">
#   <thead>
#     <tr>
#       <th id="T_83e50_level0_col0" class="col_heading level0 col0" >Split</th>
#       <th id="T_83e50_level0_col1" class="col_heading level0 col1" >R^2</th>
#       <th id="T_83e50_level0_col2" class="col_heading level0 col2" >MAE</th>
#       <th id="T_83e50_level0_col3" class="col_heading level0 col3" >RMSE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_83e50_row0_col0" class="data row0 col0" >Train</td>
#       <td id="T_83e50_row0_col1" class="data row0 col1" >0.99</td>
#       <td id="T_83e50_row0_col2" class="data row0 col2" >0.45</td>
#       <td id="T_83e50_row0_col3" class="data row0 col3" >0.71</td>
#     </tr>
#     <tr>
#       <td id="T_83e50_row1_col0" class="data row1 col0" >Test</td>
#       <td id="T_83e50_row1_col1" class="data row1 col1" >0.97</td>
#       <td id="T_83e50_row1_col2" class="data row1 col2" >1.11</td>
#       <td id="T_83e50_row1_col3" class="data row1 col3" >1.75</td>
#     </tr>
#   </tbody>
# </table>

# %%
import joblib, os

## creating a dictionary of all of the variables to save for later
export = {'X_train':X_train,
         'y_train':y_train,
         'X_test':X_test,
         'y_test':y_test,
          'preprocessor':preprocessor,
         'LinearRegression': lin_reg_drop,
          'RandomForestRegressor':rf_reg
         }

# %%
folder = "../Models/"
os.makedirs(folder, exist_ok=True)

# %%
fname = folder+'wk1-lect01-codealong.joblib'
joblib.dump(export, fname)

# %%
loaded = joblib.load(fname)
loaded.keys()

# %% [markdown]
# > We will continue working with this task and these models next class!

# %% [markdown]
# # *Teaser* Shap (For Regression)

# %%
# Import and init shap
import shap
shap.initjs()

# %%
# Take a sample of the training data
X_shap = shap.sample(X_train_df,nsamples = 500,random_state=SEED)
y_shap = y_train.loc[X_shap.index]

# Instantiate a Model Explainer with the model
explainer = shap.Explainer(rf_reg)

## Get shap values form the explainer
shap_values = explainer(X_shap,y_shap)

# %%
shap.summary_plot(shap_values, features = X_shap)
